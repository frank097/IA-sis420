# %% [markdown]
# <a href="https://colab.research.google.com/github/frank097/IA-sis420/blob/main/laboratorio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #carrera: ing. de Sistemas
# # Nombre: Franklin Correa Paco
# # Materia: Sis420
# ## github:

# %%
import time

# %%
class Nodo:
    def __init__(self, estado, hijo=None):
        self.estado = estado
        self.hijo = None
        self.padre = None
        self.set_hijo(hijo)

    def set_estado(self, estado):
        self.estado = estado

    def get_estado(self):
        return self.estado

    def set_hijo(self, hijo):
        self.hijo = hijo
        if self.hijo is not None:
            for s in self.hijo:
                s.padre = self

    def get_hijo(self):
        return self.hijo

    def set_padre(self, padre):
        self.padre = padre

    def get_padre(self):
        return self.padre

    def equal(self, Nodo):
        if self.get_estado() == Nodo.get_estado():
            return True
        else:
            return False

    def en_lista(self, lista_nodos):
        enlistado = False
        for n in lista_nodos:
            if self.equal(n):
                enlistado = True
        return enlistado

    def __str__(self):
        return str(self.get_estado())

# %%
def busqueda_BPPR(nodo_inicial, solucion, visitado):
    visitado.append(nodo_inicial.get_estado())
    if nodo_inicial.get_estado() == solucion:
        return nodo_inicial
    else:
        datos_nodo = nodo_inicial.get_estado()
        hijos = []

        # GENERAR NODOS HIJOS
        for i in range(len(datos_nodo)):
            for j in range(len(datos_nodo)):
                if i != j:
                    hijo = list(datos_nodo)
                    # print('hijo->', hijo)
                    aux = hijo[i]
                    hijo[i] = hijo[j]
                    hijo[j] = aux
                    hijos.append(Nodo(hijo))
        nodo_inicial.set_hijo(hijos)

        for nodo_hijo in nodo_inicial.get_hijo():
            if not nodo_hijo.get_estado() in visitado:
                # Recursividad
                Solution = busqueda_BPPR(nodo_hijo, solucion, visitado)
                if Solution is not None:
                    return Solution
        print('No se encontro solucion')
        return None

# %%
if __name__ == "__main__":
    num_digitos = int(
        input("Ingrese el número de dígitos: "))
    # INPUT ESTADO INICIAL
    estado_inicial = []
    for i in range(num_digitos):
        estado_inicial.append(
            int(input("Elemento {"+str(i)+"} del estado inicial: ")))
    # INPUT SOLUCION
    solucion = []
    for i in range(num_digitos):
        solucion.append(
            int(input("Elemento {"+str(i)+"} de la solución: ")))
    nodo_solucion = None
    visitado = []
    nodo_inicial = Nodo(estado_inicial)
    inicio = time.time()
    nodo_actual = busqueda_BPPR(nodo_inicial, solucion, visitado)
    fin = time.time()

    tiempo_ejecucion = fin - inicio
    resultado = []
    while nodo_actual.get_padre() is not None:
        resultado.append(nodo_actual.get_estado())
        nodo_actual = nodo_actual.get_padre()
    resultado.append(estado_inicial)
    resultado.reverse()

    for e in resultado:
        print(e)

    print('Se llego al resultado en:', tiempo_ejecucion, 'segundos')
# Out:
# Ingrese el número de dígitos: 6
# Elemento {0} del estado inicial: 6
# Elemento {1} del estado inicial: 4
# Elemento {2} del estado inicial: 5
# Elemento {3} del estado inicial: 3
# Elemento {4} del estado inicial: 2
# Elemento {5} del estado inicial: 1
# Elemento {0} de la solución: 1
# Elemento {1} de la solución: 2
# Elemento {2} de la solución: 3
# Elemento {3} de la solución: 4
# Elemento {4} de la solución: 5
# Elemento {5} de la solución: 6
# [6, 4, 5, 3, 2, 1]
# [4, 6, 5, 3, 2, 1]
# [5, 6, 4, 3, 2, 1]
# [6, 5, 4, 3, 2, 1]
# [4, 5, 6, 3, 2, 1]
# [5, 4, 6, 3, 2, 1]
# [3, 4, 6, 5, 2, 1]
# [4, 3, 6, 5, 2, 1]
# [6, 3, 4, 5, 2, 1]
# [3, 6, 4, 5, 2, 1]
# [4, 6, 3, 5, 2, 1]
# [6, 4, 3, 5, 2, 1]
# [5, 4, 3, 6, 2, 1]
# [4, 5, 3, 6, 2, 1]
# [3, 5, 4, 6, 2, 1]
# [5, 3, 4, 6, 2, 1]
# [4, 3, 5, 6, 2, 1]
# [3, 4, 5, 6, 2, 1]
# [2, 4, 5, 6, 3, 1]
# [4, 2, 5, 6, 3, 1]
# [5, 2, 4, 6, 3, 1]
# [2, 5, 4, 6, 3, 1]
# [4, 5, 2, 6, 3, 1]
# [5, 4, 2, 6, 3, 1]
# [6, 4, 2, 5, 3, 1]
# [4, 6, 2, 5, 3, 1]
# [2, 6, 4, 5, 3, 1]
# [6, 2, 4, 5, 3, 1]
# [4, 2, 6, 5, 3, 1]
# [2, 4, 6, 5, 3, 1]
# [5, 4, 6, 2, 3, 1]
# [4, 5, 6, 2, 3, 1]
# [6, 5, 4, 2, 3, 1]
# [5, 6, 4, 2, 3, 1]
# [4, 6, 5, 2, 3, 1]
# [6, 4, 5, 2, 3, 1]
# [3, 4, 5, 2, 6, 1]
# [4, 3, 5, 2, 6, 1]
# [5, 3, 4, 2, 6, 1]
# [3, 5, 4, 2, 6, 1]
# [4, 5, 3, 2, 6, 1]
# [5, 4, 3, 2, 6, 1]
# [2, 4, 3, 5, 6, 1]
# [4, 2, 3, 5, 6, 1]
# [3, 2, 4, 5, 6, 1]
# [2, 3, 4, 5, 6, 1]
# [4, 3, 2, 5, 6, 1]
# [3, 4, 2, 5, 6, 1]
# [5, 4, 2, 3, 6, 1]
# [4, 5, 2, 3, 6, 1]
# [2, 5, 4, 3, 6, 1]
# [5, 2, 4, 3, 6, 1]
# [4, 2, 5, 3, 6, 1]
# [2, 4, 5, 3, 6, 1]
# [1, 4, 5, 3, 6, 2]
# [4, 1, 5, 3, 6, 2]
# [5, 1, 4, 3, 6, 2]
# [1, 5, 4, 3, 6, 2]
# [4, 5, 1, 3, 6, 2]
# [5, 4, 1, 3, 6, 2]
# [3, 4, 1, 5, 6, 2]
# [4, 3, 1, 5, 6, 2]
# [1, 3, 4, 5, 6, 2]
# [3, 1, 4, 5, 6, 2]
# [4, 1, 3, 5, 6, 2]
# [1, 4, 3, 5, 6, 2]
# [5, 4, 3, 1, 6, 2]
# [4, 5, 3, 1, 6, 2]
# [3, 5, 4, 1, 6, 2]
# [5, 3, 4, 1, 6, 2]
# [4, 3, 5, 1, 6, 2]
# [3, 4, 5, 1, 6, 2]
# [6, 4, 5, 1, 3, 2]
# [4, 6, 5, 1, 3, 2]
# [5, 6, 4, 1, 3, 2]
# [6, 5, 4, 1, 3, 2]
# [4, 5, 6, 1, 3, 2]
# [5, 4, 6, 1, 3, 2]
# [1, 4, 6, 5, 3, 2]
# [4, 1, 6, 5, 3, 2]
# [6, 1, 4, 5, 3, 2]
# [1, 6, 4, 5, 3, 2]
# [4, 6, 1, 5, 3, 2]
# [6, 4, 1, 5, 3, 2]
# [5, 4, 1, 6, 3, 2]
# [4, 5, 1, 6, 3, 2]
# [1, 5, 4, 6, 3, 2]
# [5, 1, 4, 6, 3, 2]
# [4, 1, 5, 6, 3, 2]
# [1, 4, 5, 6, 3, 2]
# [3, 4, 5, 6, 1, 2]
# [4, 3, 5, 6, 1, 2]
# [5, 3, 4, 6, 1, 2]
# [3, 5, 4, 6, 1, 2]
# [4, 5, 3, 6, 1, 2]
# [5, 4, 3, 6, 1, 2]
# [6, 4, 3, 5, 1, 2]
# [4, 6, 3, 5, 1, 2]
# [3, 6, 4, 5, 1, 2]
# [6, 3, 4, 5, 1, 2]
# [4, 3, 6, 5, 1, 2]
# [3, 4, 6, 5, 1, 2]
# [5, 4, 6, 3, 1, 2]
# [4, 5, 6, 3, 1, 2]
# [6, 5, 4, 3, 1, 2]
# [5, 6, 4, 3, 1, 2]
# [4, 6, 5, 3, 1, 2]
# [6, 4, 5, 3, 1, 2]
# [2, 4, 5, 3, 1, 6]
# [4, 2, 5, 3, 1, 6]
# [5, 2, 4, 3, 1, 6]
# [2, 5, 4, 3, 1, 6]
# [4, 5, 2, 3, 1, 6]
# [5, 4, 2, 3, 1, 6]
# [3, 4, 2, 5, 1, 6]
# [4, 3, 2, 5, 1, 6]
# [2, 3, 4, 5, 1, 6]
# [3, 2, 4, 5, 1, 6]
# [4, 2, 3, 5, 1, 6]
# [2, 4, 3, 5, 1, 6]
# [5, 4, 3, 2, 1, 6]
# [4, 5, 3, 2, 1, 6]
# [3, 5, 4, 2, 1, 6]
# [5, 3, 4, 2, 1, 6]
# [4, 3, 5, 2, 1, 6]
# [3, 4, 5, 2, 1, 6]
# [1, 4, 5, 2, 3, 6]
# [4, 1, 5, 2, 3, 6]
# [5, 1, 4, 2, 3, 6]
# [1, 5, 4, 2, 3, 6]
# [4, 5, 1, 2, 3, 6]
# [5, 4, 1, 2, 3, 6]
# [2, 4, 1, 5, 3, 6]
# [4, 2, 1, 5, 3, 6]
# [1, 2, 4, 5, 3, 6]
# [2, 1, 4, 5, 3, 6]
# [4, 1, 2, 5, 3, 6]
# [1, 4, 2, 5, 3, 6]
# [5, 4, 2, 1, 3, 6]
# [4, 5, 2, 1, 3, 6]
# [2, 5, 4, 1, 3, 6]
# [5, 2, 4, 1, 3, 6]
# [4, 2, 5, 1, 3, 6]
# [2, 4, 5, 1, 3, 6]
# [3, 4, 5, 1, 2, 6]
# [4, 3, 5, 1, 2, 6]
# [5, 3, 4, 1, 2, 6]
# [3, 5, 4, 1, 2, 6]
# [4, 5, 3, 1, 2, 6]
# [5, 4, 3, 1, 2, 6]
# [1, 4, 3, 5, 2, 6]
# [4, 1, 3, 5, 2, 6]
# [3, 1, 4, 5, 2, 6]
# [1, 3, 4, 5, 2, 6]
# [4, 3, 1, 5, 2, 6]
# [3, 4, 1, 5, 2, 6]
# [5, 4, 1, 3, 2, 6]
# [4, 5, 1, 3, 2, 6]
# [1, 5, 4, 3, 2, 6]
# [5, 1, 4, 3, 2, 6]
# [4, 1, 5, 3, 2, 6]
# [1, 4, 5, 3, 2, 6]
# [1, 3, 5, 4, 2, 6]
# [3, 1, 5, 4, 2, 6]
# [5, 1, 3, 4, 2, 6]
# [1, 5, 3, 4, 2, 6]
# [3, 5, 1, 4, 2, 6]
# [5, 3, 1, 4, 2, 6]
# [2, 3, 1, 4, 5, 6]
# [3, 2, 1, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# Se llego al resultado en: 0.014371156692504883 segundos
